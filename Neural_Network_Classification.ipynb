# %%
#Neural Network Classification
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.utils import np_utils

import pandas as pd
link = "https://raw.githubusercontent.com/AbhiRoy96/Banknote-Authentication-UCI-Dataset/master/bank_notes.csv?fbclid=IwAR1-umhE8kqVRnLaBRGAYPCaIEEHBgfekTHZy8pAZp-a3nYl6nAvQrVAnD4"
data = pd.read_csv(link)
# Out:
#       variance  skewness  curtosis  entropy  Target
# 0      3.62160   8.66610   -2.8073 -0.44699       0
# 1      4.54590   8.16740   -2.4586 -1.46210       0
# 2      3.86600  -2.63830    1.9242  0.10645       0
# 3      3.45660   9.52280   -4.0112 -3.59440       0
# 4      0.32924  -4.45520    4.5718 -0.98880       0
# ...        ...       ...       ...      ...     ...
# 1367   0.40614   1.34920   -1.4501 -0.55949       1
# 1368  -1.38870  -4.87730    6.4774  0.34179       1
# 1369  -3.75030 -13.45860   17.5932 -2.77710       1
# 1370  -3.56370  -8.38270   12.3930 -1.28230       1
# 1371  -2.54190  -0.65804    2.6842  1.19520       1
#
# [1372 rows x 5 columns]

# %%
data
sns.pairplot(iris, hue='Target')
#X=data.values[:,:4]
#y=data.values[:,4]
X = data[['variance','skewness','curtosis','entropy']]
y = data [['Target']]
y = y.target.reshape(-1, 1)
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-a9501567f576> in <module>()
#       5 X = data[['variance','skewness','curtosis','entropy']]
#       6 y = data [['Target']]
# ----> 7 y = y.target.reshape(-1, 1)
#       8 X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %%
print(X_train.shape,y_train.shape)
# Out:
# (1097, 5) (1097, 1)

# %%
def one_hot_encode_object_array(arr):
  uniques, ids = np.unique(arr, return_inverse=True)
  return np_utils.to_categorical(ids, len(uniques))

# %%
y_train_ohe = one_hot_encode_object_array(y_train)
y_test_ohe = one_hot_encode_object_array(y_test)

# %%
model=Sequential()

model.add(Dense(5, input_shape=(4,), activation='relu', name='layer1'))

model.add(Dense(3, activation='sigmoid', name='output_layer'))

model.add(Dense(5,input_shape=(4,)))
model.add(Activation("relu",name="layer1"))
model.add(Dense(3))
model.add(Activation("sigmoid"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_14 (Dense)             (None, 5)                 25
# _________________________________________________________________
# layer1 (Activation)          (None, 5)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 18
# _________________________________________________________________
# activation_9 (Activation)    (None, 3)                 0
# ...
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train_ohe,epochs=20,batch_size=1,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-1b4df041fa6c> in <module>()
# ----> 1 model.fit(X_train,y_train_ohe,epochs=20,batch_size=1,verbose=1,validation_split=0.2)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test_ohe, verbose=1)
print("The accuracy of the Neural Network classifier on test data is = {:.2f}".format(accuracy))

# %%
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 16)                80
# _________________________________________________________________
# activation_4 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 51
# _________________________________________________________________
# activation_5 (Activation)    (None, 3)                 0
# ...
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f9618b972e3e> in <module>()
# ...

# %%
iris_data = load_iris() # load the iris dataset

print('Example data: ')
print(iris_data.data[:5])
print('Example labels: ')
print(iris_data.target[:5])

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-5b9ba35b9389> in <module>()
# ----> 1 iris_data = load_iris() # load the iris dataset
#       2
#       3 print('Example data: ')
#       4 print(iris_data.data[:5])
#       5 print('Example labels: ')
#
# NameError: name 'load_iris' is not defined
